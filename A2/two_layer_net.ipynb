# %% [markdown]
# # EECS 498-007/598-005 Assignment 2-2: Two Layer Neural Network
#
# Before we start, please put your name and UMID in following format
#
# : Firstname LASTNAME, #00000000   //   e.g.) Justin JOHNSON, #12345678

# %% [markdown]
# **Your Answer:**
# Your NAME, #XXXXXXXX

# %% [markdown]
# # Setup Code
# Before getting started, we need to run some boilerplate code to set up our environment, same as Assignment 1. You'll need to rerun this setup code each time you start the notebook.
#
# First, run this cell load the autoreload extension. This allows us to edit .py source files, and re-import them into the notebook for a seamless editing and debugging experience.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Miscellaneous

# %% [markdown]
# Run some setup code for this notebook: Import some useful packages and increase the default figure size.

# %%
import eecs598
import torch
import matplotlib.pyplot as plt
import statistics
import random
import time
# %matplotlib inline


plt.rcParams['figure.figsize'] = (10.0, 8.0)
plt.rcParams['font.size'] = 16
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %% [markdown]
# We will use GPUs to accelerate our computation in this notebook. Run the following to make sure GPUs are enabled:

# %%
if torch.cuda.is_available:
  print('Good to go!')
else:
  print('Please set GPU via Edit -> Notebook Settings.')
# Out:
# Good to go!

# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.
#
# We train the network with a softmax loss function and L2 regularization on the weight matrices. The network uses a ReLU nonlinearity after the first fully connected layer.
#
# In other words, the network has the following architecture:
#
#   input - fully connected layer - ReLU - fully connected layer - softmax
#
# The outputs of the second fully-connected layer are the scores for each class.
#
# **Note**: When you implment the regularization over W, **please DO NOT multiply the regularization term by 1/2** (no coefficient).

# %% [markdown]
# ## Play with a toy data

# %% [markdown]
# The inputs to our network will be a batch of $N$ (`num_inputs`) $D$-dimensional vectors (`input_size`); the hidden layer will have $H$ hidden units (`hidden_size`), and we will predict classification scores for $C$ categories (`num_classes`). This means that the learnable weights and biases of the network will have the following shapes:
#
# *   W1: First layer weights; has shape (D, H)
# *   b1: First layer biases; has shape (H,)
# *   W2: Second layer weights; has shape (H, C)
# *   b2: Second layer biases; has shape (C,)
#
# We will use `a2_helpers.get_toy_data` function to generate random weights for a small toy model while we implement the model.

# %% [markdown]
# ### Forward pass: compute scores
# Like in the Linear Classifiers exercise, we want to write a function that takes as input the model weights and a batch of images and labels, and returns the loss and the gradient of the loss with respect to each model parameter.
#
# However rather than attempting to implement the entire function at once, we will take a staged approach and ask you to implement the full forward and backward pass one step at a time.
#
# First we will implement the forward pass of the network which uses the weights and biases to compute scores for all inputs in `nn_forward_pass`.

# %% [markdown]
# Compute the scores and compare with the answer. The distance gap should be smaller than 1e-10.

# %%
import eecs598
from eecs598.a2_helpers import get_toy_data
from two_layer_net import nn_forward_pass

eecs598.reset_seed(0)
toy_X, toy_y, params = get_toy_data()

# YOUR_TURN: Implement the score computation part of nn_forward_pass
scores, _ = nn_forward_pass(params, toy_X)
print('Your scores:')
print(scores)
print(scores.dtype)
print()
print('correct scores:')
correct_scores = torch.tensor([
        [ 9.7003e-08, -1.1143e-07, -3.9961e-08],
        [-7.4297e-08,  1.1502e-07,  1.5685e-07],
        [-2.5860e-07,  2.2765e-07,  3.2453e-07],
        [-4.7257e-07,  9.0935e-07,  4.0368e-07],
        [-1.8395e-07,  7.9303e-08,  6.0360e-07]], dtype=torch.float32, device=scores.device)
print(correct_scores)
print()

# The difference should be very small. We get < 1e-10
scores_diff = (scores - correct_scores).abs().sum().item()
print('Difference between your scores and correct scores: %.2e' % scores_diff)
# Out:
# Your scores:
# tensor([[ 9.7003e-08, -1.1143e-07, -3.9961e-08],
#         [-7.4297e-08,  1.1502e-07,  1.5685e-07],
#         [-2.5860e-07,  2.2765e-07,  3.2453e-07],
#         [-4.7257e-07,  9.0935e-07,  4.0368e-07],
#         [-1.8395e-07,  7.9303e-08,  6.0360e-07]], device='cuda:0')
# torch.float32
#
# correct scores:
# tensor([[ 9.7003e-08, -1.1143e-07, -3.9961e-08],
#         [-7.4297e-08,  1.1502e-07,  1.5685e-07],
#         [-2.5860e-07,  2.2765e-07,  3.2453e-07],
#         [-4.7257e-07,  9.0935e-07,  4.0368e-07],
#         [-1.8395e-07,  7.9303e-08,  6.0360e-07]], device='cuda:0')
#
# Difference between your scores and correct scores: 2.24e-11

# %% [markdown]
# ### Forward pass: compute loss
# Now, we implement the first part of `nn_forward_backward` that computes the data and regularization loss.
#
# For the data loss, we will use the softmax loss. For the regularization loss we will use L2 regularization on the weight matrices `W1` and `W2`; we will not apply regularization loss to the bias vectors `b1` and `b2`.

# %% [markdown]
# First, Let's run the following to check your implementation.
#
# We compute the loss for the toy data, and compare with the answer computed by our implementation. The difference between the correct and computed loss should be less than `1e-4`.

# %%
import eecs598
from eecs598.a2_helpers import get_toy_data
from two_layer_net import nn_forward_backward

eecs598.reset_seed(0)
toy_X, toy_y, params = get_toy_data()

# YOUR_TURN: Implement the loss computation part of nn_forward_backward
loss, _ = nn_forward_backward(params, toy_X, toy_y, reg=0.05)
print('Your loss: ', loss.item())
correct_loss = 1.0986121892929077
print('Correct loss: ', correct_loss)
diff = (correct_loss - loss).item()

# should be very small, we get < 1e-4
print('Difference: %.4e' % diff)
# Out:
# Your loss:  1.0986121892929077
# Correct loss:  1.0986121892929077
# Difference: 0.0000e+00

# %% [markdown]
# ### Backward pass
# Now implement the backward pass for the entire network in `nn_forward_backward`.
#
# After doing so, we will use numeric gradient checking to see whether the analytic gradient computed by our backward pass mateches a numeric gradient.
#
# We will use the functions `eecs598.grad.compute_numeric_gradient` and `eecs598.grad.rel_error` to help with numeric gradient checking. We can learn more about these functions using the `help` command:

# %%
help(eecs598.grad.compute_numeric_gradient)
print('-' * 80)
help(eecs598.grad.rel_error)
# Out:
# Help on function compute_numeric_gradient in module eecs598.grad:
#
# compute_numeric_gradient(f, x, dLdf=None, h=1e-07)
#     Compute the numeric gradient of f at x using a finite differences
#     approximation. We use the centered difference:
#
#     df    f(x + h) - f(x - h)
#     -- ~= -------------------
#     dx           2 * h
#
#     Function can also expand this easily to intermediate layers using the
#     chain rule:
#
#     dL   df   dL
#     -- = -- * --
#     dx   dx   df
#
#     Inputs:
#     - f: A function that inputs a torch tensor and returns a torch scalar
#     - x: A torch tensor giving the point at which to compute the gradient
#     - dLdf: optional upstream gradient for intermediate layers
#     - h: epsilon used in the finite difference calculation
#     Returns:
#     - grad: A tensor of the same shape as x giving the gradient of f at x
#
# --------------------------------------------------------------------------------
# Help on function rel_error in module eecs598.grad:
#
# rel_error(x, y, eps=1e-10)
#     Compute the relative error between a pair of tensors x and y,
#     which is defined as:
#
#                             max_i |x_i - y_i]|
#     rel_error(x, y) = -------------------------------
#                       max_i |x_i| + max_i |y_i| + eps
#
#     Inputs:
#     - x, y: Tensors of the same shape
#     - eps: Small positive constant for numeric stability
#
#     Returns:
#     - rel_error: Scalar giving the relative error between x and y

# %% [markdown]
# Now we will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check.
#
# You should see relative errors less than `1e-4` for all parameters.

# %%
import eecs598
from eecs598.a2_helpers import get_toy_data
from two_layer_net import nn_forward_backward

eecs598.reset_seed(0)

reg = 0.05
toy_X, toy_y, params = get_toy_data(dtype=torch.float64)

# YOUR_TURN: Implement the gradient computation part of nn_forward_backward
#            When you implement the gradient computation part, you may need to 
#            implement the `hidden` output in nn_forward_pass, as well.
loss, grads = nn_forward_backward(params, toy_X, toy_y, reg=reg)

for param_name, grad in grads.items():
  param = params[param_name]
  f = lambda w: nn_forward_backward(params, toy_X, toy_y, reg=reg)[0]
  grad_numeric = eecs598.grad.compute_numeric_gradient(f, param)
  error = eecs598.grad.rel_error(grad, grad_numeric)
  print('%s max relative error: %e' % (param_name, error))
# Out:
# W2 max relative error: 1.138678e-06
# b2 max relative error: 1.400721e-09
# W1 max relative error: 1.309897e-06
# b1 max relative error: 8.239303e-06

# %% [markdown]
# ### Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers.
#
# Look at the function `nn_train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers.
#
# You will also have to implement `nn_predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. Your final training loss should be less than 1.0.

# %%
import eecs598
from eecs598.a2_helpers import get_toy_data
from two_layer_net import nn_forward_backward, nn_train, nn_predict

eecs598.reset_seed(0)
toy_X, toy_y, params = get_toy_data()

# YOUR_TURN: Implement the nn_train function.
#            You may need to check nn_predict function (the "pred_func") as well.
stats = nn_train(params, nn_forward_backward, nn_predict, toy_X, toy_y, toy_X, toy_y,
                 learning_rate=1e-1, reg=1e-6,
                 num_iters=200, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'], 'o')
plt.xlabel('Iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.5211755633354187

# %%
# Plot the loss function and train / validation accuracies
plt.plot(stats['train_acc_history'], 'o', label='train')
plt.plot(stats['val_acc_history'], 'o', label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Testing our NN on a real dataset: CIFAR-10
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
import eecs598

# Invoke the above function to get our data.
eecs598.reset_seed(0)
data_dict = eecs598.data.preprocess_cifar10(dtype=torch.float64)
print('Train data shape: ', data_dict['X_train'].shape)
print('Train labels shape: ', data_dict['y_train'].shape)
print('Validation data shape: ', data_dict['X_val'].shape)
print('Validation labels shape: ', data_dict['y_val'].shape)
print('Test data shape: ', data_dict['X_test'].shape)
print('Test labels shape: ', data_dict['y_test'].shape)
# Out:
# Train data shape:  torch.Size([40000, 3072])
# Train labels shape:  torch.Size([40000])
# Validation data shape:  torch.Size([10000, 3072])
# Validation labels shape:  torch.Size([10000])
# Test data shape:  torch.Size([10000, 3072])
# Test labels shape:  torch.Size([10000])

# %% [markdown]
# ### Wrap all function into a Class
# We will use the class `TwoLayerNet` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are PyTorch tensors.

# %% [markdown]
# ### Train a network
# To train our network we will use SGD. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
import eecs598
from two_layer_net import TwoLayerNet

input_size = 3 * 32 * 32
hidden_size = 36
num_classes = 10

# fix random seed before we generate a set of parameters
eecs598.reset_seed(0)
net = TwoLayerNet(input_size, hidden_size, num_classes, dtype=data_dict['X_train'].dtype, device=data_dict['X_train'].device)

# Train the network
stats = net.train(data_dict['X_train'], data_dict['y_train'],
                  data_dict['X_val'], data_dict['y_val'],
                  num_iters=500, batch_size=1000,
                  learning_rate=1e-2, learning_rate_decay=0.95,
                  reg=0.25, verbose=True)

# Predict on the validation set
y_val_pred = net.predict(data_dict['X_val'])
val_acc = 100.0 * (y_val_pred == data_dict['y_val']).double().mean().item()
print('Validation accuracy: %.2f%%' % val_acc)
# Out:
# iteration 0 / 500: loss 2.302863
# iteration 100 / 500: loss 2.302695
# iteration 200 / 500: loss 2.302669
# iteration 300 / 500: loss 2.302551
# iteration 400 / 500: loss 2.302571
# Validation accuracy: 9.77%

# %% [markdown]
# ### Debug the training
# With the default parameters we provided above, you should get a validation accuracy less than 10% on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
from eecs598.a2_helpers import plot_stats

plot_stats(stats)

# %% [markdown]
# Similar to SVM and Softmax classifier, let's visualize the weights.

# %%
from eecs598.a2_helpers import show_net_weights 

show_net_weights(net)

# %% [markdown]
# ### What's wrong?
# Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.

# %% [markdown]
# #### Capacity?
# Our initial model has very similar performance on the training and validation sets. This suggests that the model is underfitting, and that its performance might improve if we were to increase its capacity.
#
# One way we can increase the capacity of a neural network model is to increase the size of its hidden layer. Here we investigate the effect of increasing the size of the hidden layer. The performance (as measured by validation-set accuracy) should increase as the size of the hidden layer increases; however it may show diminishing returns for larger layer sizes.

# %%
import eecs598
from eecs598.a2_helpers import plot_acc_curves
from two_layer_net import TwoLayerNet

hidden_sizes = [2, 8, 32, 128] 
lr = 0.1
reg = 0.001

stat_dict = {}
for hs in hidden_sizes:
  print('train with hidden size: {}'.format(hs))
  # fix random seed before we generate a set of parameters
  eecs598.reset_seed(0)
  net = TwoLayerNet(3 * 32 * 32, hs, 10, device=data_dict['X_train'].device, dtype=data_dict['X_train'].dtype)
  stats = net.train(data_dict['X_train'], data_dict['y_train'], data_dict['X_val'], data_dict['y_val'],
            num_iters=3000, batch_size=1000,
            learning_rate=lr, learning_rate_decay=0.95,
            reg=reg, verbose=False)
  stat_dict[hs] = stats

plot_acc_curves(stat_dict)
# Out:
# train with hidden size: 2
# train with hidden size: 8
# train with hidden size: 32
# train with hidden size: 128

# %% [markdown]
# #### Regularization?
# Another possible explanation for the small gap we saw between the train and validation accuracies of our model is regularization. In particular, if the regularization coefficient were too high then the model may be unable to fit the training data.
#
# We can investigate the phenomenon empirically by training a set of models with varying regularization strengths while fixing other hyperparameters.
#
# You should see that setting the regularization strength too high will harm the validation-set performance of the model:

# %%
import eecs598
from eecs598.a2_helpers import plot_acc_curves
from two_layer_net import TwoLayerNet

hs = 128
lr = 1.0
regs = [0, 1e-5, 1e-3, 1e-1]

stat_dict = {}
for reg in regs:
  print('train with regularization: {}'.format(reg))
  # fix random seed before we generate a set of parameters
  eecs598.reset_seed(0)
  net = TwoLayerNet(3 * 32 * 32, hs, 10, device=data_dict['X_train'].device, dtype=data_dict['X_train'].dtype)
  stats = net.train(data_dict['X_train'], data_dict['y_train'], data_dict['X_val'], data_dict['y_val'],
            num_iters=3000, batch_size=1000,
            learning_rate=lr, learning_rate_decay=0.95,
            reg=reg, verbose=False)
  stat_dict[reg] = stats

plot_acc_curves(stat_dict)
# Out:
# train with regularization: 0
# train with regularization: 1e-05
# train with regularization: 0.001
# train with regularization: 0.1

# %% [markdown]
# #### Learning Rate?
# Last but not least, we also want to see the effect of learning rate with respect to the performance.

# %%
import eecs598
from eecs598.a2_helpers import plot_acc_curves
from two_layer_net import TwoLayerNet

hs = 128
lrs = [1e-4, 1e-2, 1e0, 1e2]
reg = 1e-4

stat_dict = {}
for lr in lrs:
  print('train with learning rate: {}'.format(lr))
  # fix random seed before we generate a set of parameters
  eecs598.reset_seed(0)
  net = TwoLayerNet(3 * 32 * 32, hs, 10, device=data_dict['X_train'].device, dtype=data_dict['X_train'].dtype)
  stats = net.train(data_dict['X_train'], data_dict['y_train'], data_dict['X_val'], data_dict['y_val'],
            num_iters=3000, batch_size=1000,
            learning_rate=lr, learning_rate_decay=0.95,
            reg=reg, verbose=False)
  stat_dict[lr] = stats

plot_acc_curves(stat_dict)
# Out:
# train with learning rate: 0.0001
# train with learning rate: 0.01
# train with learning rate: 1.0
# train with learning rate: 100.0

# %% [markdown]
# ### Tune your hyperparameters
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, number of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Plots**. To guide your hyperparameter search, you might consider making auxiliary plots of training and validation performance as above, or plotting the results arising from different hyperparameter combinations as we did in the Linear Classifier notebook. You should feel free to plot any auxiliary results you need in order to find a good network, but we don't require any particular plots from you.
#
# **Approximate results**. To get full credit for the assignment, you should achieve a classification accuracy above 50% on the validation set.
#
# (Our best model gets a validation-set accuracy 56.44% -- did you beat us?)

# %%
import os
import eecs598
from two_layer_net import TwoLayerNet, find_best_net, nn_get_search_params

# running this model on float64 may needs more time, so set it as float32
eecs598.reset_seed(0)
data_dict = eecs598.data.preprocess_cifar10(dtype=torch.float32)

# store the best model into this 
eecs598.reset_seed(0)
best_net, best_stat, best_val_acc = find_best_net(data_dict, nn_get_search_params)
print(best_val_acc)

plot_stats(best_stat)

# save the best model
path = os.path.join('.', 'nn_best_model.pt')
best_net.save(path)
# Out:
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302587
# iteration 200 / 1000: loss 2.302587
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302589
# iteration 500 / 1000: loss 2.302588
# iteration 600 / 1000: loss 2.302583
# iteration 700 / 1000: loss 2.302584
# iteration 800 / 1000: loss 2.302583
# iteration 900 / 1000: loss 2.302583
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302587
# iteration 200 / 1000: loss 2.302586
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302589
# iteration 500 / 1000: loss 2.302588
# iteration 600 / 1000: loss 2.302584
# iteration 700 / 1000: loss 2.302584
# iteration 800 / 1000: loss 2.302583
# iteration 900 / 1000: loss 2.302583
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302587
# iteration 200 / 1000: loss 2.302586
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302589
# iteration 500 / 1000: loss 2.302588
# iteration 600 / 1000: loss 2.302584
# iteration 700 / 1000: loss 2.302584
# iteration 800 / 1000: loss 2.302583
# iteration 900 / 1000: loss 2.302584
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302587
# iteration 200 / 1000: loss 2.302586
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302588
# iteration 500 / 1000: loss 2.302588
# iteration 600 / 1000: loss 2.302584
# iteration 700 / 1000: loss 2.302584
# iteration 800 / 1000: loss 2.302583
# iteration 900 / 1000: loss 2.302584
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302588
# iteration 200 / 1000: loss 2.302587
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302589
# iteration 500 / 1000: loss 2.302589
# iteration 600 / 1000: loss 2.302584
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302583
# iteration 900 / 1000: loss 2.302583
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302588
# iteration 200 / 1000: loss 2.302587
# iteration 300 / 1000: loss 2.302587
# iteration 400 / 1000: loss 2.302589
# iteration 500 / 1000: loss 2.302588
# iteration 600 / 1000: loss 2.302584
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302583
# iteration 900 / 1000: loss 2.302584
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302588
# iteration 200 / 1000: loss 2.302587
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302589
# iteration 500 / 1000: loss 2.302588
# iteration 600 / 1000: loss 2.302584
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302583
# iteration 900 / 1000: loss 2.302584
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302588
# iteration 200 / 1000: loss 2.302586
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302589
# iteration 500 / 1000: loss 2.302588
# iteration 600 / 1000: loss 2.302584
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302584
# iteration 900 / 1000: loss 2.302584
# iteration 0 / 1000: loss 2.302588
# iteration 100 / 1000: loss 2.302590
# iteration 200 / 1000: loss 2.302589
# iteration 300 / 1000: loss 2.302588
# iteration 400 / 1000: loss 2.302592
# iteration 500 / 1000: loss 2.302591
# iteration 600 / 1000: loss 2.302586
# iteration 700 / 1000: loss 2.302587
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302586
# iteration 0 / 1000: loss 2.302588
# iteration 100 / 1000: loss 2.302590
# iteration 200 / 1000: loss 2.302589
# iteration 300 / 1000: loss 2.302589
# iteration 400 / 1000: loss 2.302591
# iteration 500 / 1000: loss 2.302591
# iteration 600 / 1000: loss 2.302586
# iteration 700 / 1000: loss 2.302587
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302586
# iteration 0 / 1000: loss 2.302588
# iteration 100 / 1000: loss 2.302590
# iteration 200 / 1000: loss 2.302589
# iteration 300 / 1000: loss 2.302588
# iteration 400 / 1000: loss 2.302591
# iteration 500 / 1000: loss 2.302591
# iteration 600 / 1000: loss 2.302586
# iteration 700 / 1000: loss 2.302587
# iteration 800 / 1000: loss 2.302586
# iteration 900 / 1000: loss 2.302586
# iteration 0 / 1000: loss 2.302588
# iteration 100 / 1000: loss 2.302590
# iteration 200 / 1000: loss 2.302588
# iteration 300 / 1000: loss 2.302588
# iteration 400 / 1000: loss 2.302591
# iteration 500 / 1000: loss 2.302590
# iteration 600 / 1000: loss 2.302587
# iteration 700 / 1000: loss 2.302587
# iteration 800 / 1000: loss 2.302586
# iteration 900 / 1000: loss 2.302586
# iteration 0 / 1000: loss 2.302610
# iteration 100 / 1000: loss 2.302612
# iteration 200 / 1000: loss 2.302611
# iteration 300 / 1000: loss 2.302610
# iteration 400 / 1000: loss 2.302613
# iteration 500 / 1000: loss 2.302613
# iteration 600 / 1000: loss 2.302608
# iteration 700 / 1000: loss 2.302608
# iteration 800 / 1000: loss 2.302607
# iteration 900 / 1000: loss 2.302607
# iteration 0 / 1000: loss 2.302610
# iteration 100 / 1000: loss 2.302612
# iteration 200 / 1000: loss 2.302611
# iteration 300 / 1000: loss 2.302611
# iteration 400 / 1000: loss 2.302613
# iteration 500 / 1000: loss 2.302612
# iteration 600 / 1000: loss 2.302608
# iteration 700 / 1000: loss 2.302608
# iteration 800 / 1000: loss 2.302607
# iteration 900 / 1000: loss 2.302607
# iteration 0 / 1000: loss 2.302610
# iteration 100 / 1000: loss 2.302612
# iteration 200 / 1000: loss 2.302611
# iteration 300 / 1000: loss 2.302610
# iteration 400 / 1000: loss 2.302613
# iteration 500 / 1000: loss 2.302613
# iteration 600 / 1000: loss 2.302608
# iteration 700 / 1000: loss 2.302608
# iteration 800 / 1000: loss 2.302607
# iteration 900 / 1000: loss 2.302608
# iteration 0 / 1000: loss 2.302610
# iteration 100 / 1000: loss 2.302612
# iteration 200 / 1000: loss 2.302611
# iteration 300 / 1000: loss 2.302610
# iteration 400 / 1000: loss 2.302613
# iteration 500 / 1000: loss 2.302612
# iteration 600 / 1000: loss 2.302608
# iteration 700 / 1000: loss 2.302608
# iteration 800 / 1000: loss 2.302608
# iteration 900 / 1000: loss 2.302608
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302588
# iteration 200 / 1000: loss 2.302587
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302589
# iteration 500 / 1000: loss 2.302588
# iteration 600 / 1000: loss 2.302583
# iteration 700 / 1000: loss 2.302584
# iteration 800 / 1000: loss 2.302583
# iteration 900 / 1000: loss 2.302583
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302587
# iteration 200 / 1000: loss 2.302587
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302589
# iteration 500 / 1000: loss 2.302588
# iteration 600 / 1000: loss 2.302584
# iteration 700 / 1000: loss 2.302584
# iteration 800 / 1000: loss 2.302583
# iteration 900 / 1000: loss 2.302583
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302587
# iteration 200 / 1000: loss 2.302586
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302589
# iteration 500 / 1000: loss 2.302588
# iteration 600 / 1000: loss 2.302584
# iteration 700 / 1000: loss 2.302584
# iteration 800 / 1000: loss 2.302583
# iteration 900 / 1000: loss 2.302583
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302587
# iteration 200 / 1000: loss 2.302586
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302588
# iteration 500 / 1000: loss 2.302588
# iteration 600 / 1000: loss 2.302584
# iteration 700 / 1000: loss 2.302584
# iteration 800 / 1000: loss 2.302583
# iteration 900 / 1000: loss 2.302584
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302588
# iteration 200 / 1000: loss 2.302587
# iteration 300 / 1000: loss 2.302587
# iteration 400 / 1000: loss 2.302590
# iteration 500 / 1000: loss 2.302589
# iteration 600 / 1000: loss 2.302584
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302583
# iteration 900 / 1000: loss 2.302584
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302588
# iteration 200 / 1000: loss 2.302587
# iteration 300 / 1000: loss 2.302587
# iteration 400 / 1000: loss 2.302589
# iteration 500 / 1000: loss 2.302589
# iteration 600 / 1000: loss 2.302584
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302583
# iteration 900 / 1000: loss 2.302584
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302588
# iteration 200 / 1000: loss 2.302587
# iteration 300 / 1000: loss 2.302587
# iteration 400 / 1000: loss 2.302589
# iteration 500 / 1000: loss 2.302589
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302584
# iteration 900 / 1000: loss 2.302584
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302588
# iteration 200 / 1000: loss 2.302587
# iteration 300 / 1000: loss 2.302587
# iteration 400 / 1000: loss 2.302589
# iteration 500 / 1000: loss 2.302588
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302584
# iteration 900 / 1000: loss 2.302584
# iteration 0 / 1000: loss 2.302590
# iteration 100 / 1000: loss 2.302593
# iteration 200 / 1000: loss 2.302592
# iteration 300 / 1000: loss 2.302591
# iteration 400 / 1000: loss 2.302594
# iteration 500 / 1000: loss 2.302593
# iteration 600 / 1000: loss 2.302588
# iteration 700 / 1000: loss 2.302589
# iteration 800 / 1000: loss 2.302588
# iteration 900 / 1000: loss 2.302588
# iteration 0 / 1000: loss 2.302590
# iteration 100 / 1000: loss 2.302592
# iteration 200 / 1000: loss 2.302592
# iteration 300 / 1000: loss 2.302591
# iteration 400 / 1000: loss 2.302594
# iteration 500 / 1000: loss 2.302593
# iteration 600 / 1000: loss 2.302589
# iteration 700 / 1000: loss 2.302589
# iteration 800 / 1000: loss 2.302588
# iteration 900 / 1000: loss 2.302588
# iteration 0 / 1000: loss 2.302590
# iteration 100 / 1000: loss 2.302592
# iteration 200 / 1000: loss 2.302591
# iteration 300 / 1000: loss 2.302591
# iteration 400 / 1000: loss 2.302594
# iteration 500 / 1000: loss 2.302593
# iteration 600 / 1000: loss 2.302589
# iteration 700 / 1000: loss 2.302589
# iteration 800 / 1000: loss 2.302588
# iteration 900 / 1000: loss 2.302588
# iteration 0 / 1000: loss 2.302590
# iteration 100 / 1000: loss 2.302592
# iteration 200 / 1000: loss 2.302591
# iteration 300 / 1000: loss 2.302591
# iteration 400 / 1000: loss 2.302593
# iteration 500 / 1000: loss 2.302593
# iteration 600 / 1000: loss 2.302589
# iteration 700 / 1000: loss 2.302589
# iteration 800 / 1000: loss 2.302588
# iteration 900 / 1000: loss 2.302589
# iteration 0 / 1000: loss 2.302634
# iteration 100 / 1000: loss 2.302637
# iteration 200 / 1000: loss 2.302635
# iteration 300 / 1000: loss 2.302635
# iteration 400 / 1000: loss 2.302638
# iteration 500 / 1000: loss 2.302637
# iteration 600 / 1000: loss 2.302632
# iteration 700 / 1000: loss 2.302632
# iteration 800 / 1000: loss 2.302630
# iteration 900 / 1000: loss 2.302631
# iteration 0 / 1000: loss 2.302634
# iteration 100 / 1000: loss 2.302636
# iteration 200 / 1000: loss 2.302635
# iteration 300 / 1000: loss 2.302635
# iteration 400 / 1000: loss 2.302637
# iteration 500 / 1000: loss 2.302637
# iteration 600 / 1000: loss 2.302632
# iteration 700 / 1000: loss 2.302632
# iteration 800 / 1000: loss 2.302631
# iteration 900 / 1000: loss 2.302631
# iteration 0 / 1000: loss 2.302634
# iteration 100 / 1000: loss 2.302636
# iteration 200 / 1000: loss 2.302635
# iteration 300 / 1000: loss 2.302635
# iteration 400 / 1000: loss 2.302637
# iteration 500 / 1000: loss 2.302637
# iteration 600 / 1000: loss 2.302633
# iteration 700 / 1000: loss 2.302633
# iteration 800 / 1000: loss 2.302631
# iteration 900 / 1000: loss 2.302631
# iteration 0 / 1000: loss 2.302634
# iteration 100 / 1000: loss 2.302636
# iteration 200 / 1000: loss 2.302635
# iteration 300 / 1000: loss 2.302635
# iteration 400 / 1000: loss 2.302637
# iteration 500 / 1000: loss 2.302636
# iteration 600 / 1000: loss 2.302633
# iteration 700 / 1000: loss 2.302633
# iteration 800 / 1000: loss 2.302632
# iteration 900 / 1000: loss 2.302632
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302588
# iteration 200 / 1000: loss 2.302587
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302589
# iteration 500 / 1000: loss 2.302588
# iteration 600 / 1000: loss 2.302583
# iteration 700 / 1000: loss 2.302584
# iteration 800 / 1000: loss 2.302583
# iteration 900 / 1000: loss 2.302583
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302587
# iteration 200 / 1000: loss 2.302586
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302589
# iteration 500 / 1000: loss 2.302588
# iteration 600 / 1000: loss 2.302583
# iteration 700 / 1000: loss 2.302584
# iteration 800 / 1000: loss 2.302583
# iteration 900 / 1000: loss 2.302583
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302587
# iteration 200 / 1000: loss 2.302586
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302588
# iteration 500 / 1000: loss 2.302588
# iteration 600 / 1000: loss 2.302584
# iteration 700 / 1000: loss 2.302584
# iteration 800 / 1000: loss 2.302583
# iteration 900 / 1000: loss 2.302583
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302587
# iteration 200 / 1000: loss 2.302586
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302588
# iteration 500 / 1000: loss 2.302588
# iteration 600 / 1000: loss 2.302584
# iteration 700 / 1000: loss 2.302584
# iteration 800 / 1000: loss 2.302583
# iteration 900 / 1000: loss 2.302584
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302588
# iteration 200 / 1000: loss 2.302588
# iteration 300 / 1000: loss 2.302587
# iteration 400 / 1000: loss 2.302590
# iteration 500 / 1000: loss 2.302589
# iteration 600 / 1000: loss 2.302584
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302584
# iteration 900 / 1000: loss 2.302584
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302588
# iteration 200 / 1000: loss 2.302587
# iteration 300 / 1000: loss 2.302587
# iteration 400 / 1000: loss 2.302590
# iteration 500 / 1000: loss 2.302589
# iteration 600 / 1000: loss 2.302584
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302584
# iteration 900 / 1000: loss 2.302584
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302588
# iteration 200 / 1000: loss 2.302587
# iteration 300 / 1000: loss 2.302587
# iteration 400 / 1000: loss 2.302589
# iteration 500 / 1000: loss 2.302589
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302584
# iteration 900 / 1000: loss 2.302584
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302588
# iteration 200 / 1000: loss 2.302587
# iteration 300 / 1000: loss 2.302587
# iteration 400 / 1000: loss 2.302589
# iteration 500 / 1000: loss 2.302589
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302584
# iteration 900 / 1000: loss 2.302585
# iteration 0 / 1000: loss 2.302595
# iteration 100 / 1000: loss 2.302598
# iteration 200 / 1000: loss 2.302597
# iteration 300 / 1000: loss 2.302596
# iteration 400 / 1000: loss 2.302599
# iteration 500 / 1000: loss 2.302598
# iteration 600 / 1000: loss 2.302593
# iteration 700 / 1000: loss 2.302594
# iteration 800 / 1000: loss 2.302593
# iteration 900 / 1000: loss 2.302593
# iteration 0 / 1000: loss 2.302595
# iteration 100 / 1000: loss 2.302597
# iteration 200 / 1000: loss 2.302596
# iteration 300 / 1000: loss 2.302596
# iteration 400 / 1000: loss 2.302599
# iteration 500 / 1000: loss 2.302598
# iteration 600 / 1000: loss 2.302593
# iteration 700 / 1000: loss 2.302594
# iteration 800 / 1000: loss 2.302593
# iteration 900 / 1000: loss 2.302593
# iteration 0 / 1000: loss 2.302595
# iteration 100 / 1000: loss 2.302597
# iteration 200 / 1000: loss 2.302596
# iteration 300 / 1000: loss 2.302596
# iteration 400 / 1000: loss 2.302598
# iteration 500 / 1000: loss 2.302598
# iteration 600 / 1000: loss 2.302594
# iteration 700 / 1000: loss 2.302594
# iteration 800 / 1000: loss 2.302593
# iteration 900 / 1000: loss 2.302593
# iteration 0 / 1000: loss 2.302595
# iteration 100 / 1000: loss 2.302597
# iteration 200 / 1000: loss 2.302596
# iteration 300 / 1000: loss 2.302596
# iteration 400 / 1000: loss 2.302598
# iteration 500 / 1000: loss 2.302598
# iteration 600 / 1000: loss 2.302594
# iteration 700 / 1000: loss 2.302594
# iteration 800 / 1000: loss 2.302593
# iteration 900 / 1000: loss 2.302594
# iteration 0 / 1000: loss 2.302684
# iteration 100 / 1000: loss 2.302686
# iteration 200 / 1000: loss 2.302685
# iteration 300 / 1000: loss 2.302684
# iteration 400 / 1000: loss 2.302687
# iteration 500 / 1000: loss 2.302686
# iteration 600 / 1000: loss 2.302680
# iteration 700 / 1000: loss 2.302681
# iteration 800 / 1000: loss 2.302679
# iteration 900 / 1000: loss 2.302679
# iteration 0 / 1000: loss 2.302684
# iteration 100 / 1000: loss 2.302686
# iteration 200 / 1000: loss 2.302685
# iteration 300 / 1000: loss 2.302684
# iteration 400 / 1000: loss 2.302686
# iteration 500 / 1000: loss 2.302685
# iteration 600 / 1000: loss 2.302680
# iteration 700 / 1000: loss 2.302681
# iteration 800 / 1000: loss 2.302679
# iteration 900 / 1000: loss 2.302680
# iteration 0 / 1000: loss 2.302684
# iteration 100 / 1000: loss 2.302686
# iteration 200 / 1000: loss 2.302685
# iteration 300 / 1000: loss 2.302684
# iteration 400 / 1000: loss 2.302686
# iteration 500 / 1000: loss 2.302686
# iteration 600 / 1000: loss 2.302681
# iteration 700 / 1000: loss 2.302681
# iteration 800 / 1000: loss 2.302680
# iteration 900 / 1000: loss 2.302680
# iteration 0 / 1000: loss 2.302684
# iteration 100 / 1000: loss 2.302686
# iteration 200 / 1000: loss 2.302685
# iteration 300 / 1000: loss 2.302684
# iteration 400 / 1000: loss 2.302686
# iteration 500 / 1000: loss 2.302685
# iteration 600 / 1000: loss 2.302682
# iteration 700 / 1000: loss 2.302682
# iteration 800 / 1000: loss 2.302680
# iteration 900 / 1000: loss 2.302681
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302609
# iteration 200 / 1000: loss 2.302599
# iteration 300 / 1000: loss 2.302596
# iteration 400 / 1000: loss 2.302624
# iteration 500 / 1000: loss 2.302618
# iteration 600 / 1000: loss 2.302570
# iteration 700 / 1000: loss 2.302578
# iteration 800 / 1000: loss 2.302561
# iteration 900 / 1000: loss 2.302568
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302608
# iteration 200 / 1000: loss 2.302598
# iteration 300 / 1000: loss 2.302596
# iteration 400 / 1000: loss 2.302622
# iteration 500 / 1000: loss 2.302617
# iteration 600 / 1000: loss 2.302572
# iteration 700 / 1000: loss 2.302578
# iteration 800 / 1000: loss 2.302565
# iteration 900 / 1000: loss 2.302570
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302607
# iteration 200 / 1000: loss 2.302598
# iteration 300 / 1000: loss 2.302595
# iteration 400 / 1000: loss 2.302620
# iteration 500 / 1000: loss 2.302615
# iteration 600 / 1000: loss 2.302575
# iteration 700 / 1000: loss 2.302579
# iteration 800 / 1000: loss 2.302568
# iteration 900 / 1000: loss 2.302572
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302605
# iteration 200 / 1000: loss 2.302597
# iteration 300 / 1000: loss 2.302595
# iteration 400 / 1000: loss 2.302618
# iteration 500 / 1000: loss 2.302613
# iteration 600 / 1000: loss 2.302577
# iteration 700 / 1000: loss 2.302579
# iteration 800 / 1000: loss 2.302570
# iteration 900 / 1000: loss 2.302575
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302609
# iteration 200 / 1000: loss 2.302599
# iteration 300 / 1000: loss 2.302597
# iteration 400 / 1000: loss 2.302624
# iteration 500 / 1000: loss 2.302619
# iteration 600 / 1000: loss 2.302570
# iteration 700 / 1000: loss 2.302579
# iteration 800 / 1000: loss 2.302562
# iteration 900 / 1000: loss 2.302568
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302608
# iteration 200 / 1000: loss 2.302599
# iteration 300 / 1000: loss 2.302596
# iteration 400 / 1000: loss 2.302622
# iteration 500 / 1000: loss 2.302617
# iteration 600 / 1000: loss 2.302573
# iteration 700 / 1000: loss 2.302579
# iteration 800 / 1000: loss 2.302565
# iteration 900 / 1000: loss 2.302570
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302607
# iteration 200 / 1000: loss 2.302598
# iteration 300 / 1000: loss 2.302595
# iteration 400 / 1000: loss 2.302620
# iteration 500 / 1000: loss 2.302615
# iteration 600 / 1000: loss 2.302575
# iteration 700 / 1000: loss 2.302579
# iteration 800 / 1000: loss 2.302568
# iteration 900 / 1000: loss 2.302573
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302605
# iteration 200 / 1000: loss 2.302597
# iteration 300 / 1000: loss 2.302595
# iteration 400 / 1000: loss 2.302619
# iteration 500 / 1000: loss 2.302613
# iteration 600 / 1000: loss 2.302577
# iteration 700 / 1000: loss 2.302579
# iteration 800 / 1000: loss 2.302571
# iteration 900 / 1000: loss 2.302575
# iteration 0 / 1000: loss 2.302588
# iteration 100 / 1000: loss 2.302611
# iteration 200 / 1000: loss 2.302602
# iteration 300 / 1000: loss 2.302599
# iteration 400 / 1000: loss 2.302627
# iteration 500 / 1000: loss 2.302621
# iteration 600 / 1000: loss 2.302572
# iteration 700 / 1000: loss 2.302581
# iteration 800 / 1000: loss 2.302564
# iteration 900 / 1000: loss 2.302570
# iteration 0 / 1000: loss 2.302588
# iteration 100 / 1000: loss 2.302610
# iteration 200 / 1000: loss 2.302601
# iteration 300 / 1000: loss 2.302598
# iteration 400 / 1000: loss 2.302624
# iteration 500 / 1000: loss 2.302619
# iteration 600 / 1000: loss 2.302575
# iteration 700 / 1000: loss 2.302581
# iteration 800 / 1000: loss 2.302567
# iteration 900 / 1000: loss 2.302572
# iteration 0 / 1000: loss 2.302588
# iteration 100 / 1000: loss 2.302609
# iteration 200 / 1000: loss 2.302600
# iteration 300 / 1000: loss 2.302598
# iteration 400 / 1000: loss 2.302623
# iteration 500 / 1000: loss 2.302617
# iteration 600 / 1000: loss 2.302577
# iteration 700 / 1000: loss 2.302581
# iteration 800 / 1000: loss 2.302570
# iteration 900 / 1000: loss 2.302575
# iteration 0 / 1000: loss 2.302588
# iteration 100 / 1000: loss 2.302608
# iteration 200 / 1000: loss 2.302599
# iteration 300 / 1000: loss 2.302597
# iteration 400 / 1000: loss 2.302621
# iteration 500 / 1000: loss 2.302616
# iteration 600 / 1000: loss 2.302579
# iteration 700 / 1000: loss 2.302582
# iteration 800 / 1000: loss 2.302573
# iteration 900 / 1000: loss 2.302577
# iteration 0 / 1000: loss 2.302610
# iteration 100 / 1000: loss 2.302633
# iteration 200 / 1000: loss 2.302622
# iteration 300 / 1000: loss 2.302618
# iteration 400 / 1000: loss 2.302645
# iteration 500 / 1000: loss 2.302639
# iteration 600 / 1000: loss 2.302589
# iteration 700 / 1000: loss 2.302597
# iteration 800 / 1000: loss 2.302579
# iteration 900 / 1000: loss 2.302585
# iteration 0 / 1000: loss 2.302610
# iteration 100 / 1000: loss 2.302631
# iteration 200 / 1000: loss 2.302621
# iteration 300 / 1000: loss 2.302618
# iteration 400 / 1000: loss 2.302644
# iteration 500 / 1000: loss 2.302637
# iteration 600 / 1000: loss 2.302592
# iteration 700 / 1000: loss 2.302598
# iteration 800 / 1000: loss 2.302583
# iteration 900 / 1000: loss 2.302588
# iteration 0 / 1000: loss 2.302610
# iteration 100 / 1000: loss 2.302630
# iteration 200 / 1000: loss 2.302621
# iteration 300 / 1000: loss 2.302617
# iteration 400 / 1000: loss 2.302642
# iteration 500 / 1000: loss 2.302636
# iteration 600 / 1000: loss 2.302595
# iteration 700 / 1000: loss 2.302599
# iteration 800 / 1000: loss 2.302587
# iteration 900 / 1000: loss 2.302591
# iteration 0 / 1000: loss 2.302610
# iteration 100 / 1000: loss 2.302629
# iteration 200 / 1000: loss 2.302620
# iteration 300 / 1000: loss 2.302617
# iteration 400 / 1000: loss 2.302640
# iteration 500 / 1000: loss 2.302634
# iteration 600 / 1000: loss 2.302598
# iteration 700 / 1000: loss 2.302599
# iteration 800 / 1000: loss 2.302590
# iteration 900 / 1000: loss 2.302594
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302609
# iteration 200 / 1000: loss 2.302599
# iteration 300 / 1000: loss 2.302596
# iteration 400 / 1000: loss 2.302624
# iteration 500 / 1000: loss 2.302618
# iteration 600 / 1000: loss 2.302570
# iteration 700 / 1000: loss 2.302578
# iteration 800 / 1000: loss 2.302561
# iteration 900 / 1000: loss 2.302568
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302608
# iteration 200 / 1000: loss 2.302598
# iteration 300 / 1000: loss 2.302596
# iteration 400 / 1000: loss 2.302622
# iteration 500 / 1000: loss 2.302617
# iteration 600 / 1000: loss 2.302572
# iteration 700 / 1000: loss 2.302578
# iteration 800 / 1000: loss 2.302565
# iteration 900 / 1000: loss 2.302570
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302607
# iteration 200 / 1000: loss 2.302598
# iteration 300 / 1000: loss 2.302595
# iteration 400 / 1000: loss 2.302620
# iteration 500 / 1000: loss 2.302615
# iteration 600 / 1000: loss 2.302575
# iteration 700 / 1000: loss 2.302579
# iteration 800 / 1000: loss 2.302568
# iteration 900 / 1000: loss 2.302572
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302605
# iteration 200 / 1000: loss 2.302597
# iteration 300 / 1000: loss 2.302595
# iteration 400 / 1000: loss 2.302618
# iteration 500 / 1000: loss 2.302613
# iteration 600 / 1000: loss 2.302577
# iteration 700 / 1000: loss 2.302579
# iteration 800 / 1000: loss 2.302570
# iteration 900 / 1000: loss 2.302575
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302609
# iteration 200 / 1000: loss 2.302600
# iteration 300 / 1000: loss 2.302597
# iteration 400 / 1000: loss 2.302625
# iteration 500 / 1000: loss 2.302619
# iteration 600 / 1000: loss 2.302571
# iteration 700 / 1000: loss 2.302579
# iteration 800 / 1000: loss 2.302562
# iteration 900 / 1000: loss 2.302568
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302608
# iteration 200 / 1000: loss 2.302599
# iteration 300 / 1000: loss 2.302596
# iteration 400 / 1000: loss 2.302623
# iteration 500 / 1000: loss 2.302617
# iteration 600 / 1000: loss 2.302573
# iteration 700 / 1000: loss 2.302579
# iteration 800 / 1000: loss 2.302565
# iteration 900 / 1000: loss 2.302571
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302607
# iteration 200 / 1000: loss 2.302598
# iteration 300 / 1000: loss 2.302596
# iteration 400 / 1000: loss 2.302621
# iteration 500 / 1000: loss 2.302615
# iteration 600 / 1000: loss 2.302576
# iteration 700 / 1000: loss 2.302579
# iteration 800 / 1000: loss 2.302568
# iteration 900 / 1000: loss 2.302573
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302606
# iteration 200 / 1000: loss 2.302598
# iteration 300 / 1000: loss 2.302595
# iteration 400 / 1000: loss 2.302619
# iteration 500 / 1000: loss 2.302614
# iteration 600 / 1000: loss 2.302577
# iteration 700 / 1000: loss 2.302579
# iteration 800 / 1000: loss 2.302571
# iteration 900 / 1000: loss 2.302575
# iteration 0 / 1000: loss 2.302590
# iteration 100 / 1000: loss 2.302614
# iteration 200 / 1000: loss 2.302604
# iteration 300 / 1000: loss 2.302601
# iteration 400 / 1000: loss 2.302629
# iteration 500 / 1000: loss 2.302623
# iteration 600 / 1000: loss 2.302575
# iteration 700 / 1000: loss 2.302583
# iteration 800 / 1000: loss 2.302566
# iteration 900 / 1000: loss 2.302572
# iteration 0 / 1000: loss 2.302590
# iteration 100 / 1000: loss 2.302613
# iteration 200 / 1000: loss 2.302603
# iteration 300 / 1000: loss 2.302601
# iteration 400 / 1000: loss 2.302627
# iteration 500 / 1000: loss 2.302621
# iteration 600 / 1000: loss 2.302577
# iteration 700 / 1000: loss 2.302583
# iteration 800 / 1000: loss 2.302569
# iteration 900 / 1000: loss 2.302575
# iteration 0 / 1000: loss 2.302590
# iteration 100 / 1000: loss 2.302612
# iteration 200 / 1000: loss 2.302603
# iteration 300 / 1000: loss 2.302600
# iteration 400 / 1000: loss 2.302625
# iteration 500 / 1000: loss 2.302619
# iteration 600 / 1000: loss 2.302580
# iteration 700 / 1000: loss 2.302584
# iteration 800 / 1000: loss 2.302572
# iteration 900 / 1000: loss 2.302577
# iteration 0 / 1000: loss 2.302590
# iteration 100 / 1000: loss 2.302610
# iteration 200 / 1000: loss 2.302602
# iteration 300 / 1000: loss 2.302600
# iteration 400 / 1000: loss 2.302623
# iteration 500 / 1000: loss 2.302618
# iteration 600 / 1000: loss 2.302582
# iteration 700 / 1000: loss 2.302584
# iteration 800 / 1000: loss 2.302575
# iteration 900 / 1000: loss 2.302579
# iteration 0 / 1000: loss 2.302634
# iteration 100 / 1000: loss 2.302656
# iteration 200 / 1000: loss 2.302645
# iteration 300 / 1000: loss 2.302640
# iteration 400 / 1000: loss 2.302666
# iteration 500 / 1000: loss 2.302659
# iteration 600 / 1000: loss 2.302609
# iteration 700 / 1000: loss 2.302616
# iteration 800 / 1000: loss 2.302597
# iteration 900 / 1000: loss 2.302602
# iteration 0 / 1000: loss 2.302634
# iteration 100 / 1000: loss 2.302655
# iteration 200 / 1000: loss 2.302644
# iteration 300 / 1000: loss 2.302640
# iteration 400 / 1000: loss 2.302665
# iteration 500 / 1000: loss 2.302658
# iteration 600 / 1000: loss 2.302612
# iteration 700 / 1000: loss 2.302617
# iteration 800 / 1000: loss 2.302602
# iteration 900 / 1000: loss 2.302606
# iteration 0 / 1000: loss 2.302634
# iteration 100 / 1000: loss 2.302654
# iteration 200 / 1000: loss 2.302644
# iteration 300 / 1000: loss 2.302639
# iteration 400 / 1000: loss 2.302663
# iteration 500 / 1000: loss 2.302656
# iteration 600 / 1000: loss 2.302615
# iteration 700 / 1000: loss 2.302619
# iteration 800 / 1000: loss 2.302606
# iteration 900 / 1000: loss 2.302610
# iteration 0 / 1000: loss 2.302634
# iteration 100 / 1000: loss 2.302653
# iteration 200 / 1000: loss 2.302643
# iteration 300 / 1000: loss 2.302639
# iteration 400 / 1000: loss 2.302662
# iteration 500 / 1000: loss 2.302656
# iteration 600 / 1000: loss 2.302618
# iteration 700 / 1000: loss 2.302619
# iteration 800 / 1000: loss 2.302610
# iteration 900 / 1000: loss 2.302614
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302609
# iteration 200 / 1000: loss 2.302599
# iteration 300 / 1000: loss 2.302596
# iteration 400 / 1000: loss 2.302624
# iteration 500 / 1000: loss 2.302618
# iteration 600 / 1000: loss 2.302570
# iteration 700 / 1000: loss 2.302578
# iteration 800 / 1000: loss 2.302561
# iteration 900 / 1000: loss 2.302568
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302608
# iteration 200 / 1000: loss 2.302598
# iteration 300 / 1000: loss 2.302596
# iteration 400 / 1000: loss 2.302622
# iteration 500 / 1000: loss 2.302617
# iteration 600 / 1000: loss 2.302572
# iteration 700 / 1000: loss 2.302578
# iteration 800 / 1000: loss 2.302565
# iteration 900 / 1000: loss 2.302570
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302606
# iteration 200 / 1000: loss 2.302598
# iteration 300 / 1000: loss 2.302595
# iteration 400 / 1000: loss 2.302620
# iteration 500 / 1000: loss 2.302615
# iteration 600 / 1000: loss 2.302575
# iteration 700 / 1000: loss 2.302579
# iteration 800 / 1000: loss 2.302567
# iteration 900 / 1000: loss 2.302572
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302606
# iteration 200 / 1000: loss 2.302597
# iteration 300 / 1000: loss 2.302595
# iteration 400 / 1000: loss 2.302618
# iteration 500 / 1000: loss 2.302613
# iteration 600 / 1000: loss 2.302577
# iteration 700 / 1000: loss 2.302579
# iteration 800 / 1000: loss 2.302570
# iteration 900 / 1000: loss 2.302575
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302610
# iteration 200 / 1000: loss 2.302600
# iteration 300 / 1000: loss 2.302597
# iteration 400 / 1000: loss 2.302625
# iteration 500 / 1000: loss 2.302619
# iteration 600 / 1000: loss 2.302571
# iteration 700 / 1000: loss 2.302579
# iteration 800 / 1000: loss 2.302562
# iteration 900 / 1000: loss 2.302569
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302609
# iteration 200 / 1000: loss 2.302599
# iteration 300 / 1000: loss 2.302597
# iteration 400 / 1000: loss 2.302623
# iteration 500 / 1000: loss 2.302618
# iteration 600 / 1000: loss 2.302573
# iteration 700 / 1000: loss 2.302579
# iteration 800 / 1000: loss 2.302566
# iteration 900 / 1000: loss 2.302571
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302607
# iteration 200 / 1000: loss 2.302598
# iteration 300 / 1000: loss 2.302596
# iteration 400 / 1000: loss 2.302621
# iteration 500 / 1000: loss 2.302616
# iteration 600 / 1000: loss 2.302576
# iteration 700 / 1000: loss 2.302580
# iteration 800 / 1000: loss 2.302568
# iteration 900 / 1000: loss 2.302573
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302607
# iteration 200 / 1000: loss 2.302598
# iteration 300 / 1000: loss 2.302596
# iteration 400 / 1000: loss 2.302619
# iteration 500 / 1000: loss 2.302614
# iteration 600 / 1000: loss 2.302578
# iteration 700 / 1000: loss 2.302580
# iteration 800 / 1000: loss 2.302571
# iteration 900 / 1000: loss 2.302576
# iteration 0 / 1000: loss 2.302595
# iteration 100 / 1000: loss 2.302619
# iteration 200 / 1000: loss 2.302609
# iteration 300 / 1000: loss 2.302606
# iteration 400 / 1000: loss 2.302634
# iteration 500 / 1000: loss 2.302628
# iteration 600 / 1000: loss 2.302580
# iteration 700 / 1000: loss 2.302588
# iteration 800 / 1000: loss 2.302571
# iteration 900 / 1000: loss 2.302577
# iteration 0 / 1000: loss 2.302595
# iteration 100 / 1000: loss 2.302618
# iteration 200 / 1000: loss 2.302608
# iteration 300 / 1000: loss 2.302606
# iteration 400 / 1000: loss 2.302632
# iteration 500 / 1000: loss 2.302626
# iteration 600 / 1000: loss 2.302582
# iteration 700 / 1000: loss 2.302588
# iteration 800 / 1000: loss 2.302574
# iteration 900 / 1000: loss 2.302580
# iteration 0 / 1000: loss 2.302595
# iteration 100 / 1000: loss 2.302616
# iteration 200 / 1000: loss 2.302607
# iteration 300 / 1000: loss 2.302605
# iteration 400 / 1000: loss 2.302630
# iteration 500 / 1000: loss 2.302624
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302589
# iteration 800 / 1000: loss 2.302577
# iteration 900 / 1000: loss 2.302582
# iteration 0 / 1000: loss 2.302595
# iteration 100 / 1000: loss 2.302615
# iteration 200 / 1000: loss 2.302607
# iteration 300 / 1000: loss 2.302604
# iteration 400 / 1000: loss 2.302628
# iteration 500 / 1000: loss 2.302623
# iteration 600 / 1000: loss 2.302587
# iteration 700 / 1000: loss 2.302589
# iteration 800 / 1000: loss 2.302580
# iteration 900 / 1000: loss 2.302584
# iteration 0 / 1000: loss 2.302684
# iteration 100 / 1000: loss 2.302704
# iteration 200 / 1000: loss 2.302691
# iteration 300 / 1000: loss 2.302684
# iteration 400 / 1000: loss 2.302708
# iteration 500 / 1000: loss 2.302699
# iteration 600 / 1000: loss 2.302648
# iteration 700 / 1000: loss 2.302653
# iteration 800 / 1000: loss 2.302633
# iteration 900 / 1000: loss 2.302637
# iteration 0 / 1000: loss 2.302684
# iteration 100 / 1000: loss 2.302703
# iteration 200 / 1000: loss 2.302690
# iteration 300 / 1000: loss 2.302685
# iteration 400 / 1000: loss 2.302708
# iteration 500 / 1000: loss 2.302699
# iteration 600 / 1000: loss 2.302652
# iteration 700 / 1000: loss 2.302656
# iteration 800 / 1000: loss 2.302639
# iteration 900 / 1000: loss 2.302643
# iteration 0 / 1000: loss 2.302684
# iteration 100 / 1000: loss 2.302702
# iteration 200 / 1000: loss 2.302690
# iteration 300 / 1000: loss 2.302685
# iteration 400 / 1000: loss 2.302707
# iteration 500 / 1000: loss 2.302699
# iteration 600 / 1000: loss 2.302656
# iteration 700 / 1000: loss 2.302658
# iteration 800 / 1000: loss 2.302645
# iteration 900 / 1000: loss 2.302648
# iteration 0 / 1000: loss 2.302684
# iteration 100 / 1000: loss 2.302701
# iteration 200 / 1000: loss 2.302690
# iteration 300 / 1000: loss 2.302685
# iteration 400 / 1000: loss 2.302706
# iteration 500 / 1000: loss 2.302699
# iteration 600 / 1000: loss 2.302660
# iteration 700 / 1000: loss 2.302660
# iteration 800 / 1000: loss 2.302650
# iteration 900 / 1000: loss 2.302653
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302818
# iteration 200 / 1000: loss 2.302717
# iteration 300 / 1000: loss 2.302691
# iteration 400 / 1000: loss 2.302901
# iteration 500 / 1000: loss 2.302833
# iteration 600 / 1000: loss 2.302437
# iteration 700 / 1000: loss 2.302539
# iteration 800 / 1000: loss 2.302376
# iteration 900 / 1000: loss 2.302361
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302807
# iteration 200 / 1000: loss 2.302711
# iteration 300 / 1000: loss 2.302686
# iteration 400 / 1000: loss 2.302890
# iteration 500 / 1000: loss 2.302827
# iteration 600 / 1000: loss 2.302460
# iteration 700 / 1000: loss 2.302545
# iteration 800 / 1000: loss 2.302418
# iteration 900 / 1000: loss 2.302454
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302796
# iteration 200 / 1000: loss 2.302705
# iteration 300 / 1000: loss 2.302682
# iteration 400 / 1000: loss 2.302878
# iteration 500 / 1000: loss 2.302820
# iteration 600 / 1000: loss 2.302481
# iteration 700 / 1000: loss 2.302547
# iteration 800 / 1000: loss 2.302444
# iteration 900 / 1000: loss 2.302483
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302785
# iteration 200 / 1000: loss 2.302698
# iteration 300 / 1000: loss 2.302677
# iteration 400 / 1000: loss 2.302866
# iteration 500 / 1000: loss 2.302812
# iteration 600 / 1000: loss 2.302500
# iteration 700 / 1000: loss 2.302547
# iteration 800 / 1000: loss 2.302464
# iteration 900 / 1000: loss 2.302497
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302818
# iteration 200 / 1000: loss 2.302717
# iteration 300 / 1000: loss 2.302691
# iteration 400 / 1000: loss 2.302901
# iteration 500 / 1000: loss 2.302834
# iteration 600 / 1000: loss 2.302437
# iteration 700 / 1000: loss 2.302540
# iteration 800 / 1000: loss 2.302377
# iteration 900 / 1000: loss 2.302366
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302807
# iteration 200 / 1000: loss 2.302711
# iteration 300 / 1000: loss 2.302687
# iteration 400 / 1000: loss 2.302890
# iteration 500 / 1000: loss 2.302828
# iteration 600 / 1000: loss 2.302460
# iteration 700 / 1000: loss 2.302545
# iteration 800 / 1000: loss 2.302418
# iteration 900 / 1000: loss 2.302456
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302796
# iteration 200 / 1000: loss 2.302705
# iteration 300 / 1000: loss 2.302682
# iteration 400 / 1000: loss 2.302878
# iteration 500 / 1000: loss 2.302821
# iteration 600 / 1000: loss 2.302481
# iteration 700 / 1000: loss 2.302547
# iteration 800 / 1000: loss 2.302444
# iteration 900 / 1000: loss 2.302483
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302785
# iteration 200 / 1000: loss 2.302699
# iteration 300 / 1000: loss 2.302677
# iteration 400 / 1000: loss 2.302866
# iteration 500 / 1000: loss 2.302812
# iteration 600 / 1000: loss 2.302500
# iteration 700 / 1000: loss 2.302547
# iteration 800 / 1000: loss 2.302465
# iteration 900 / 1000: loss 2.302497
# iteration 0 / 1000: loss 2.302588
# iteration 100 / 1000: loss 2.302820
# iteration 200 / 1000: loss 2.302719
# iteration 300 / 1000: loss 2.302693
# iteration 400 / 1000: loss 2.302903
# iteration 500 / 1000: loss 2.302836
# iteration 600 / 1000: loss 2.302440
# iteration 700 / 1000: loss 2.302545
# iteration 800 / 1000: loss 2.302388
# iteration 900 / 1000: loss 2.302402
# iteration 0 / 1000: loss 2.302588
# iteration 100 / 1000: loss 2.302809
# iteration 200 / 1000: loss 2.302713
# iteration 300 / 1000: loss 2.302689
# iteration 400 / 1000: loss 2.302892
# iteration 500 / 1000: loss 2.302830
# iteration 600 / 1000: loss 2.302462
# iteration 700 / 1000: loss 2.302548
# iteration 800 / 1000: loss 2.302423
# iteration 900 / 1000: loss 2.302466
# iteration 0 / 1000: loss 2.302588
# iteration 100 / 1000: loss 2.302798
# iteration 200 / 1000: loss 2.302707
# iteration 300 / 1000: loss 2.302684
# iteration 400 / 1000: loss 2.302880
# iteration 500 / 1000: loss 2.302823
# iteration 600 / 1000: loss 2.302483
# iteration 700 / 1000: loss 2.302549
# iteration 800 / 1000: loss 2.302447
# iteration 900 / 1000: loss 2.302487
# iteration 0 / 1000: loss 2.302588
# iteration 100 / 1000: loss 2.302787
# iteration 200 / 1000: loss 2.302701
# iteration 300 / 1000: loss 2.302679
# iteration 400 / 1000: loss 2.302868
# iteration 500 / 1000: loss 2.302814
# iteration 600 / 1000: loss 2.302502
# iteration 700 / 1000: loss 2.302549
# iteration 800 / 1000: loss 2.302467
# iteration 900 / 1000: loss 2.302500
# iteration 0 / 1000: loss 2.302610
# iteration 100 / 1000: loss 2.302834
# iteration 200 / 1000: loss 2.302728
# iteration 300 / 1000: loss 2.302698
# iteration 400 / 1000: loss 2.302906
# iteration 500 / 1000: loss 2.302838
# iteration 600 / 1000: loss 2.302442
# iteration 700 / 1000: loss 2.302553
# iteration 800 / 1000: loss 2.302412
# iteration 900 / 1000: loss 2.302484
# iteration 0 / 1000: loss 2.302610
# iteration 100 / 1000: loss 2.302824
# iteration 200 / 1000: loss 2.302722
# iteration 300 / 1000: loss 2.302695
# iteration 400 / 1000: loss 2.302896
# iteration 500 / 1000: loss 2.302832
# iteration 600 / 1000: loss 2.302464
# iteration 700 / 1000: loss 2.302552
# iteration 800 / 1000: loss 2.302431
# iteration 900 / 1000: loss 2.302488
# iteration 0 / 1000: loss 2.302610
# iteration 100 / 1000: loss 2.302813
# iteration 200 / 1000: loss 2.302716
# iteration 300 / 1000: loss 2.302691
# iteration 400 / 1000: loss 2.302885
# iteration 500 / 1000: loss 2.302825
# iteration 600 / 1000: loss 2.302485
# iteration 700 / 1000: loss 2.302552
# iteration 800 / 1000: loss 2.302450
# iteration 900 / 1000: loss 2.302494
# iteration 0 / 1000: loss 2.302610
# iteration 100 / 1000: loss 2.302802
# iteration 200 / 1000: loss 2.302711
# iteration 300 / 1000: loss 2.302686
# iteration 400 / 1000: loss 2.302873
# iteration 500 / 1000: loss 2.302818
# iteration 600 / 1000: loss 2.302505
# iteration 700 / 1000: loss 2.302552
# iteration 800 / 1000: loss 2.302469
# iteration 900 / 1000: loss 2.302503
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302818
# iteration 200 / 1000: loss 2.302716
# iteration 300 / 1000: loss 2.302690
# iteration 400 / 1000: loss 2.302896
# iteration 500 / 1000: loss 2.302820
# iteration 600 / 1000: loss 2.302394
# iteration 700 / 1000: loss 2.302312
# iteration 800 / 1000: loss 2.301754
# iteration 900 / 1000: loss 2.300006
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302807
# iteration 200 / 1000: loss 2.302710
# iteration 300 / 1000: loss 2.302685
# iteration 400 / 1000: loss 2.302886
# iteration 500 / 1000: loss 2.302820
# iteration 600 / 1000: loss 2.302439
# iteration 700 / 1000: loss 2.302456
# iteration 800 / 1000: loss 2.302226
# iteration 900 / 1000: loss 2.301908
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302796
# iteration 200 / 1000: loss 2.302704
# iteration 300 / 1000: loss 2.302681
# iteration 400 / 1000: loss 2.302876
# iteration 500 / 1000: loss 2.302816
# iteration 600 / 1000: loss 2.302470
# iteration 700 / 1000: loss 2.302509
# iteration 800 / 1000: loss 2.302377
# iteration 900 / 1000: loss 2.302333
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302785
# iteration 200 / 1000: loss 2.302698
# iteration 300 / 1000: loss 2.302677
# iteration 400 / 1000: loss 2.302864
# iteration 500 / 1000: loss 2.302809
# iteration 600 / 1000: loss 2.302494
# iteration 700 / 1000: loss 2.302530
# iteration 800 / 1000: loss 2.302439
# iteration 900 / 1000: loss 2.302450
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302818
# iteration 200 / 1000: loss 2.302717
# iteration 300 / 1000: loss 2.302690
# iteration 400 / 1000: loss 2.302897
# iteration 500 / 1000: loss 2.302821
# iteration 600 / 1000: loss 2.302396
# iteration 700 / 1000: loss 2.302319
# iteration 800 / 1000: loss 2.301774
# iteration 900 / 1000: loss 2.300089
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302807
# iteration 200 / 1000: loss 2.302711
# iteration 300 / 1000: loss 2.302686
# iteration 400 / 1000: loss 2.302887
# iteration 500 / 1000: loss 2.302820
# iteration 600 / 1000: loss 2.302440
# iteration 700 / 1000: loss 2.302459
# iteration 800 / 1000: loss 2.302233
# iteration 900 / 1000: loss 2.301926
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302796
# iteration 200 / 1000: loss 2.302705
# iteration 300 / 1000: loss 2.302681
# iteration 400 / 1000: loss 2.302876
# iteration 500 / 1000: loss 2.302816
# iteration 600 / 1000: loss 2.302470
# iteration 700 / 1000: loss 2.302510
# iteration 800 / 1000: loss 2.302380
# iteration 900 / 1000: loss 2.302338
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302785
# iteration 200 / 1000: loss 2.302698
# iteration 300 / 1000: loss 2.302677
# iteration 400 / 1000: loss 2.302865
# iteration 500 / 1000: loss 2.302809
# iteration 600 / 1000: loss 2.302494
# iteration 700 / 1000: loss 2.302531
# iteration 800 / 1000: loss 2.302440
# iteration 900 / 1000: loss 2.302451
# iteration 0 / 1000: loss 2.302590
# iteration 100 / 1000: loss 2.302822
# iteration 200 / 1000: loss 2.302721
# iteration 300 / 1000: loss 2.302694
# iteration 400 / 1000: loss 2.302901
# iteration 500 / 1000: loss 2.302827
# iteration 600 / 1000: loss 2.302409
# iteration 700 / 1000: loss 2.302378
# iteration 800 / 1000: loss 2.301949
# iteration 900 / 1000: loss 2.300787
# iteration 0 / 1000: loss 2.302590
# iteration 100 / 1000: loss 2.302812
# iteration 200 / 1000: loss 2.302715
# iteration 300 / 1000: loss 2.302690
# iteration 400 / 1000: loss 2.302891
# iteration 500 / 1000: loss 2.302825
# iteration 600 / 1000: loss 2.302448
# iteration 700 / 1000: loss 2.302483
# iteration 800 / 1000: loss 2.302284
# iteration 900 / 1000: loss 2.302077
# iteration 0 / 1000: loss 2.302590
# iteration 100 / 1000: loss 2.302801
# iteration 200 / 1000: loss 2.302709
# iteration 300 / 1000: loss 2.302685
# iteration 400 / 1000: loss 2.302880
# iteration 500 / 1000: loss 2.302821
# iteration 600 / 1000: loss 2.302476
# iteration 700 / 1000: loss 2.302522
# iteration 800 / 1000: loss 2.302399
# iteration 900 / 1000: loss 2.302378
# iteration 0 / 1000: loss 2.302590
# iteration 100 / 1000: loss 2.302790
# iteration 200 / 1000: loss 2.302702
# iteration 300 / 1000: loss 2.302681
# iteration 400 / 1000: loss 2.302869
# iteration 500 / 1000: loss 2.302814
# iteration 600 / 1000: loss 2.302499
# iteration 700 / 1000: loss 2.302538
# iteration 800 / 1000: loss 2.302449
# iteration 900 / 1000: loss 2.302465
# iteration 0 / 1000: loss 2.302634
# iteration 100 / 1000: loss 2.302851
# iteration 200 / 1000: loss 2.302739
# iteration 300 / 1000: loss 2.302705
# iteration 400 / 1000: loss 2.302911
# iteration 500 / 1000: loss 2.302840
# iteration 600 / 1000: loss 2.302442
# iteration 700 / 1000: loss 2.302544
# iteration 800 / 1000: loss 2.302394
# iteration 900 / 1000: loss 2.302436
# iteration 0 / 1000: loss 2.302634
# iteration 100 / 1000: loss 2.302840
# iteration 200 / 1000: loss 2.302734
# iteration 300 / 1000: loss 2.302702
# iteration 400 / 1000: loss 2.302901
# iteration 500 / 1000: loss 2.302835
# iteration 600 / 1000: loss 2.302466
# iteration 700 / 1000: loss 2.302549
# iteration 800 / 1000: loss 2.302425
# iteration 900 / 1000: loss 2.302471
# iteration 0 / 1000: loss 2.302634
# iteration 100 / 1000: loss 2.302830
# iteration 200 / 1000: loss 2.302728
# iteration 300 / 1000: loss 2.302699
# iteration 400 / 1000: loss 2.302891
# iteration 500 / 1000: loss 2.302830
# iteration 600 / 1000: loss 2.302488
# iteration 700 / 1000: loss 2.302551
# iteration 800 / 1000: loss 2.302449
# iteration 900 / 1000: loss 2.302489
# iteration 0 / 1000: loss 2.302634
# iteration 100 / 1000: loss 2.302820
# iteration 200 / 1000: loss 2.302723
# iteration 300 / 1000: loss 2.302696
# iteration 400 / 1000: loss 2.302880
# iteration 500 / 1000: loss 2.302823
# iteration 600 / 1000: loss 2.302508
# iteration 700 / 1000: loss 2.302553
# iteration 800 / 1000: loss 2.302470
# iteration 900 / 1000: loss 2.302502
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302818
# iteration 200 / 1000: loss 2.302716
# iteration 300 / 1000: loss 2.302689
# iteration 400 / 1000: loss 2.302896
# iteration 500 / 1000: loss 2.302819
# iteration 600 / 1000: loss 2.302389
# iteration 700 / 1000: loss 2.302293
# iteration 800 / 1000: loss 2.301706
# iteration 900 / 1000: loss 2.299870
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302807
# iteration 200 / 1000: loss 2.302710
# iteration 300 / 1000: loss 2.302685
# iteration 400 / 1000: loss 2.302886
# iteration 500 / 1000: loss 2.302819
# iteration 600 / 1000: loss 2.302437
# iteration 700 / 1000: loss 2.302450
# iteration 800 / 1000: loss 2.302213
# iteration 900 / 1000: loss 2.301882
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302796
# iteration 200 / 1000: loss 2.302704
# iteration 300 / 1000: loss 2.302681
# iteration 400 / 1000: loss 2.302876
# iteration 500 / 1000: loss 2.302815
# iteration 600 / 1000: loss 2.302469
# iteration 700 / 1000: loss 2.302506
# iteration 800 / 1000: loss 2.302373
# iteration 900 / 1000: loss 2.302328
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302785
# iteration 200 / 1000: loss 2.302698
# iteration 300 / 1000: loss 2.302676
# iteration 400 / 1000: loss 2.302864
# iteration 500 / 1000: loss 2.302809
# iteration 600 / 1000: loss 2.302493
# iteration 700 / 1000: loss 2.302529
# iteration 800 / 1000: loss 2.302437
# iteration 900 / 1000: loss 2.302448
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302819
# iteration 200 / 1000: loss 2.302717
# iteration 300 / 1000: loss 2.302690
# iteration 400 / 1000: loss 2.302897
# iteration 500 / 1000: loss 2.302821
# iteration 600 / 1000: loss 2.302392
# iteration 700 / 1000: loss 2.302301
# iteration 800 / 1000: loss 2.301729
# iteration 900 / 1000: loss 2.299958
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302808
# iteration 200 / 1000: loss 2.302711
# iteration 300 / 1000: loss 2.302686
# iteration 400 / 1000: loss 2.302887
# iteration 500 / 1000: loss 2.302821
# iteration 600 / 1000: loss 2.302438
# iteration 700 / 1000: loss 2.302453
# iteration 800 / 1000: loss 2.302220
# iteration 900 / 1000: loss 2.301901
# ...
# iteration 500 / 1000: loss 1.971378
# iteration 600 / 1000: loss 1.928487
# iteration 700 / 1000: loss 1.763564
# iteration 800 / 1000: loss 1.796221
# iteration 900 / 1000: loss 1.783870
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.304245
# iteration 200 / 1000: loss 2.176975
# iteration 300 / 1000: loss 2.033639
# iteration 400 / 1000: loss 1.956826
# iteration 500 / 1000: loss 1.927985
# iteration 600 / 1000: loss 1.832863
# iteration 700 / 1000: loss 1.677234
# iteration 800 / 1000: loss 1.718876
# iteration 900 / 1000: loss 1.730780
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.304242
# iteration 200 / 1000: loss 2.191071
# iteration 300 / 1000: loss 2.051180
# iteration 400 / 1000: loss 1.975933
# iteration 500 / 1000: loss 1.942810
# iteration 600 / 1000: loss 1.866690
# iteration 700 / 1000: loss 1.696601
# iteration 800 / 1000: loss 1.743862
# iteration 900 / 1000: loss 1.752478
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.304216
# iteration 200 / 1000: loss 2.207524
# iteration 300 / 1000: loss 2.073484
# iteration 400 / 1000: loss 1.989716
# iteration 500 / 1000: loss 1.959638
# iteration 600 / 1000: loss 1.909553
# iteration 700 / 1000: loss 1.731062
# iteration 800 / 1000: loss 1.765697
# iteration 900 / 1000: loss 1.770617
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.304169
# iteration 200 / 1000: loss 2.223978
# iteration 300 / 1000: loss 2.097984
# iteration 400 / 1000: loss 2.005425
# iteration 500 / 1000: loss 1.977418
# iteration 600 / 1000: loss 1.936235
# iteration 700 / 1000: loss 1.773578
# iteration 800 / 1000: loss 1.804866
# iteration 900 / 1000: loss 1.793127
# iteration 0 / 1000: loss 2.302588
# iteration 100 / 1000: loss 2.304296
# iteration 200 / 1000: loss 2.195842
# iteration 300 / 1000: loss 2.070829
# iteration 400 / 1000: loss 2.006552
# iteration 500 / 1000: loss 1.999330
# iteration 600 / 1000: loss 1.937369
# iteration 700 / 1000: loss 1.785020
# iteration 800 / 1000: loss 1.830680
# iteration 900 / 1000: loss 1.838436
# iteration 0 / 1000: loss 2.302588
# iteration 100 / 1000: loss 2.304272
# iteration 200 / 1000: loss 2.208958
# iteration 300 / 1000: loss 2.089826
# iteration 400 / 1000: loss 2.018792
# iteration 500 / 1000: loss 2.007161
# iteration 600 / 1000: loss 1.963123
# iteration 700 / 1000: loss 1.804772
# iteration 800 / 1000: loss 1.840160
# iteration 900 / 1000: loss 1.845080
# iteration 0 / 1000: loss 2.302588
# iteration 100 / 1000: loss 2.304234
# iteration 200 / 1000: loss 2.222968
# iteration 300 / 1000: loss 2.109313
# iteration 400 / 1000: loss 2.028828
# iteration 500 / 1000: loss 2.017744
# iteration 600 / 1000: loss 1.985931
# iteration 700 / 1000: loss 1.828994
# iteration 800 / 1000: loss 1.860712
# iteration 900 / 1000: loss 1.856684
# iteration 0 / 1000: loss 2.302588
# iteration 100 / 1000: loss 2.304180
# iteration 200 / 1000: loss 2.237628
# iteration 300 / 1000: loss 2.128482
# iteration 400 / 1000: loss 2.043220
# iteration 500 / 1000: loss 2.033573
# iteration 600 / 1000: loss 2.005076
# iteration 700 / 1000: loss 1.858240
# iteration 800 / 1000: loss 1.895916
# iteration 900 / 1000: loss 1.880242
# iteration 0 / 1000: loss 2.302610
# iteration 100 / 1000: loss 2.304400
# iteration 200 / 1000: loss 2.297458
# iteration 300 / 1000: loss 2.244467
# iteration 400 / 1000: loss 2.233685
# iteration 500 / 1000: loss 2.244459
# iteration 600 / 1000: loss 2.244129
# iteration 700 / 1000: loss 2.147003
# iteration 800 / 1000: loss 2.183238
# iteration 900 / 1000: loss 2.185239
# iteration 0 / 1000: loss 2.302610
# iteration 100 / 1000: loss 2.304337
# iteration 200 / 1000: loss 2.300445
# iteration 300 / 1000: loss 2.248116
# iteration 400 / 1000: loss 2.236425
# iteration 500 / 1000: loss 2.246348
# iteration 600 / 1000: loss 2.245934
# iteration 700 / 1000: loss 2.151007
# iteration 800 / 1000: loss 2.187810
# iteration 900 / 1000: loss 2.188567
# iteration 0 / 1000: loss 2.302610
# iteration 100 / 1000: loss 2.304271
# iteration 200 / 1000: loss 2.301982
# iteration 300 / 1000: loss 2.253078
# iteration 400 / 1000: loss 2.239522
# iteration 500 / 1000: loss 2.248502
# iteration 600 / 1000: loss 2.248609
# iteration 700 / 1000: loss 2.160110
# iteration 800 / 1000: loss 2.193678
# iteration 900 / 1000: loss 2.192518
# iteration 0 / 1000: loss 2.302610
# iteration 100 / 1000: loss 2.304202
# iteration 200 / 1000: loss 2.302649
# iteration 300 / 1000: loss 2.260647
# iteration 400 / 1000: loss 2.242805
# iteration 500 / 1000: loss 2.250515
# iteration 600 / 1000: loss 2.251842
# iteration 700 / 1000: loss 2.174576
# iteration 800 / 1000: loss 2.202055
# iteration 900 / 1000: loss 2.197657
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.299984
# iteration 200 / 1000: loss 2.144027
# iteration 300 / 1000: loss 1.995687
# iteration 400 / 1000: loss 1.892962
# iteration 500 / 1000: loss 1.892136
# iteration 600 / 1000: loss 1.767538
# iteration 700 / 1000: loss 1.618091
# iteration 800 / 1000: loss 1.650683
# iteration 900 / 1000: loss 1.642778
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.301815
# iteration 200 / 1000: loss 2.155617
# iteration 300 / 1000: loss 2.008702
# iteration 400 / 1000: loss 1.912655
# iteration 500 / 1000: loss 1.915988
# iteration 600 / 1000: loss 1.794986
# iteration 700 / 1000: loss 1.643027
# iteration 800 / 1000: loss 1.676915
# iteration 900 / 1000: loss 1.668687
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302855
# iteration 200 / 1000: loss 2.168020
# iteration 300 / 1000: loss 2.022876
# iteration 400 / 1000: loss 1.931507
# iteration 500 / 1000: loss 1.936590
# iteration 600 / 1000: loss 1.828996
# iteration 700 / 1000: loss 1.681479
# iteration 800 / 1000: loss 1.709783
# iteration 900 / 1000: loss 1.700662
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.303402
# iteration 200 / 1000: loss 2.181636
# iteration 300 / 1000: loss 2.040171
# iteration 400 / 1000: loss 1.949715
# iteration 500 / 1000: loss 1.953052
# iteration 600 / 1000: loss 1.871032
# iteration 700 / 1000: loss 1.719548
# iteration 800 / 1000: loss 1.740285
# iteration 900 / 1000: loss 1.723598
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.300139
# iteration 200 / 1000: loss 2.146724
# iteration 300 / 1000: loss 1.999942
# iteration 400 / 1000: loss 1.900425
# iteration 500 / 1000: loss 1.902350
# iteration 600 / 1000: loss 1.780885
# iteration 700 / 1000: loss 1.634599
# iteration 800 / 1000: loss 1.666340
# iteration 900 / 1000: loss 1.661861
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.301901
# iteration 200 / 1000: loss 2.157816
# iteration 300 / 1000: loss 2.013603
# iteration 400 / 1000: loss 1.920483
# iteration 500 / 1000: loss 1.926699
# iteration 600 / 1000: loss 1.806224
# iteration 700 / 1000: loss 1.659963
# iteration 800 / 1000: loss 1.694779
# iteration 900 / 1000: loss 1.689270
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302902
# iteration 200 / 1000: loss 2.170113
# iteration 300 / 1000: loss 2.026481
# iteration 400 / 1000: loss 1.937264
# iteration 500 / 1000: loss 1.944446
# iteration 600 / 1000: loss 1.840476
# iteration 700 / 1000: loss 1.694067
# iteration 800 / 1000: loss 1.722525
# iteration 900 / 1000: loss 1.714134
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.303427
# iteration 200 / 1000: loss 2.183320
# iteration 300 / 1000: loss 2.044496
# iteration 400 / 1000: loss 1.955839
# iteration 500 / 1000: loss 1.959095
# iteration 600 / 1000: loss 1.883661
# iteration 700 / 1000: loss 1.732914
# iteration 800 / 1000: loss 1.753565
# iteration 900 / 1000: loss 1.737309
# iteration 0 / 1000: loss 2.302590
# iteration 100 / 1000: loss 2.301417
# iteration 200 / 1000: loss 2.168970
# iteration 300 / 1000: loss 2.042327
# iteration 400 / 1000: loss 1.965905
# iteration 500 / 1000: loss 1.996252
# iteration 600 / 1000: loss 1.901232
# iteration 700 / 1000: loss 1.764299
# iteration 800 / 1000: loss 1.800292
# iteration 900 / 1000: loss 1.798405
# iteration 0 / 1000: loss 2.302590
# iteration 100 / 1000: loss 2.302617
# iteration 200 / 1000: loss 2.178392
# iteration 300 / 1000: loss 2.051903
# iteration 400 / 1000: loss 1.976996
# iteration 500 / 1000: loss 2.004970
# iteration 600 / 1000: loss 1.920459
# iteration 700 / 1000: loss 1.784024
# iteration 800 / 1000: loss 1.814159
# iteration 900 / 1000: loss 1.804110
# iteration 0 / 1000: loss 2.302590
# iteration 100 / 1000: loss 2.303294
# iteration 200 / 1000: loss 2.188837
# iteration 300 / 1000: loss 2.063442
# iteration 400 / 1000: loss 1.988955
# iteration 500 / 1000: loss 2.012728
# iteration 600 / 1000: loss 1.946965
# iteration 700 / 1000: loss 1.803403
# iteration 800 / 1000: loss 1.828556
# iteration 900 / 1000: loss 1.816888
# iteration 0 / 1000: loss 2.302590
# iteration 100 / 1000: loss 2.303642
# iteration 200 / 1000: loss 2.199860
# iteration 300 / 1000: loss 2.080497
# iteration 400 / 1000: loss 2.002872
# iteration 500 / 1000: loss 2.019556
# iteration 600 / 1000: loss 1.968984
# iteration 700 / 1000: loss 1.830577
# iteration 800 / 1000: loss 1.851892
# iteration 900 / 1000: loss 1.834690
# iteration 0 / 1000: loss 2.302634
# iteration 100 / 1000: loss 2.304332
# iteration 200 / 1000: loss 2.273658
# iteration 300 / 1000: loss 2.238521
# iteration 400 / 1000: loss 2.218213
# iteration 500 / 1000: loss 2.241290
# iteration 600 / 1000: loss 2.239363
# iteration 700 / 1000: loss 2.146339
# iteration 800 / 1000: loss 2.177669
# iteration 900 / 1000: loss 2.178997
# iteration 0 / 1000: loss 2.302634
# iteration 100 / 1000: loss 2.304291
# iteration 200 / 1000: loss 2.277173
# iteration 300 / 1000: loss 2.241044
# iteration 400 / 1000: loss 2.227098
# iteration 500 / 1000: loss 2.242009
# iteration 600 / 1000: loss 2.240954
# iteration 700 / 1000: loss 2.148827
# iteration 800 / 1000: loss 2.180232
# iteration 900 / 1000: loss 2.181395
# iteration 0 / 1000: loss 2.302634
# iteration 100 / 1000: loss 2.304241
# iteration 200 / 1000: loss 2.282881
# iteration 300 / 1000: loss 2.243865
# iteration 400 / 1000: loss 2.233392
# iteration 500 / 1000: loss 2.243499
# iteration 600 / 1000: loss 2.242640
# iteration 700 / 1000: loss 2.152236
# iteration 800 / 1000: loss 2.183459
# iteration 900 / 1000: loss 2.183449
# iteration 0 / 1000: loss 2.302634
# iteration 100 / 1000: loss 2.304183
# iteration 200 / 1000: loss 2.289803
# iteration 300 / 1000: loss 2.247196
# iteration 400 / 1000: loss 2.237412
# iteration 500 / 1000: loss 2.246722
# iteration 600 / 1000: loss 2.245047
# iteration 700 / 1000: loss 2.159156
# iteration 800 / 1000: loss 2.187755
# iteration 900 / 1000: loss 2.186707
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.299267
# iteration 200 / 1000: loss 2.144502
# iteration 300 / 1000: loss 1.993838
# iteration 400 / 1000: loss 1.892565
# iteration 500 / 1000: loss 1.887100
# iteration 600 / 1000: loss 1.768737
# iteration 700 / 1000: loss 1.605656
# iteration 800 / 1000: loss 1.635842
# iteration 900 / 1000: loss 1.611693
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.301408
# iteration 200 / 1000: loss 2.156890
# iteration 300 / 1000: loss 2.007334
# iteration 400 / 1000: loss 1.913155
# iteration 500 / 1000: loss 1.911577
# iteration 600 / 1000: loss 1.798476
# iteration 700 / 1000: loss 1.642412
# iteration 800 / 1000: loss 1.675553
# iteration 900 / 1000: loss 1.651272
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.302613
# iteration 200 / 1000: loss 2.169449
# iteration 300 / 1000: loss 2.020641
# iteration 400 / 1000: loss 1.930598
# iteration 500 / 1000: loss 1.938332
# iteration 600 / 1000: loss 1.827317
# iteration 700 / 1000: loss 1.679974
# iteration 800 / 1000: loss 1.713391
# iteration 900 / 1000: loss 1.685023
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 2.303276
# iteration 200 / 1000: loss 2.182067
# iteration 300 / 1000: loss 2.037904
# iteration 400 / 1000: loss 1.947219
# iteration 500 / 1000: loss 1.956823
# iteration 600 / 1000: loss 1.866955
# iteration 700 / 1000: loss 1.714507
# iteration 800 / 1000: loss 1.744428
# iteration 900 / 1000: loss 1.715798
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.299446
# iteration 200 / 1000: loss 2.146991
# iteration 300 / 1000: loss 1.998659
# iteration 400 / 1000: loss 1.900601
# iteration 500 / 1000: loss 1.898320
# iteration 600 / 1000: loss 1.779392
# iteration 700 / 1000: loss 1.626790
# iteration 800 / 1000: loss 1.654202
# iteration 900 / 1000: loss 1.639249
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.301508
# iteration 200 / 1000: loss 2.159166
# iteration 300 / 1000: loss 2.011198
# iteration 400 / 1000: loss 1.918452
# iteration 500 / 1000: loss 1.921287
# iteration 600 / 1000: loss 1.811435
# iteration 700 / 1000: loss 1.657928
# iteration 800 / 1000: loss 1.694899
# iteration 900 / 1000: loss 1.671415
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302668
# iteration 200 / 1000: loss 2.171383
# iteration 300 / 1000: loss 2.024740
# iteration 400 / 1000: loss 1.936441
# iteration 500 / 1000: loss 1.947894
# iteration 600 / 1000: loss 1.839425
# iteration 700 / 1000: loss 1.694478
# iteration 800 / 1000: loss 1.726902
# iteration 900 / 1000: loss 1.700855
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.303305
# iteration 200 / 1000: loss 2.183746
# iteration 300 / 1000: loss 2.041728
# iteration 400 / 1000: loss 1.952652
# iteration 500 / 1000: loss 1.963980
# iteration 600 / 1000: loss 1.878487
# iteration 700 / 1000: loss 1.726251
# iteration 800 / 1000: loss 1.756104
# iteration 900 / 1000: loss 1.730213
# iteration 0 / 1000: loss 2.302595
# iteration 100 / 1000: loss 2.300934
# iteration 200 / 1000: loss 2.170167
# iteration 300 / 1000: loss 2.040069
# iteration 400 / 1000: loss 1.964106
# iteration 500 / 1000: loss 1.991846
# iteration 600 / 1000: loss 1.900137
# iteration 700 / 1000: loss 1.768548
# iteration 800 / 1000: loss 1.800848
# iteration 900 / 1000: loss 1.798831
# iteration 0 / 1000: loss 2.302595
# iteration 100 / 1000: loss 2.302341
# iteration 200 / 1000: loss 2.179687
# iteration 300 / 1000: loss 2.049267
# iteration 400 / 1000: loss 1.975196
# iteration 500 / 1000: loss 2.007209
# iteration 600 / 1000: loss 1.918024
# iteration 700 / 1000: loss 1.785780
# iteration 800 / 1000: loss 1.817683
# iteration 900 / 1000: loss 1.806568
# iteration 0 / 1000: loss 2.302595
# iteration 100 / 1000: loss 2.303128
# iteration 200 / 1000: loss 2.189232
# iteration 300 / 1000: loss 2.061484
# iteration 400 / 1000: loss 1.986544
# iteration 500 / 1000: loss 2.016451
# iteration 600 / 1000: loss 1.945787
# iteration 700 / 1000: loss 1.803548
# iteration 800 / 1000: loss 1.836469
# iteration 900 / 1000: loss 1.819956
# iteration 0 / 1000: loss 2.302595
# iteration 100 / 1000: loss 2.303556
# iteration 200 / 1000: loss 2.199705
# iteration 300 / 1000: loss 2.078944
# iteration 400 / 1000: loss 2.000749
# iteration 500 / 1000: loss 2.024051
# iteration 600 / 1000: loss 1.969532
# iteration 700 / 1000: loss 1.824942
# iteration 800 / 1000: loss 1.855273
# iteration 900 / 1000: loss 1.832386
# iteration 0 / 1000: loss 2.302684
# iteration 100 / 1000: loss 2.304321
# iteration 200 / 1000: loss 2.273121
# iteration 300 / 1000: loss 2.238225
# iteration 400 / 1000: loss 2.217043
# iteration 500 / 1000: loss 2.241082
# iteration 600 / 1000: loss 2.240004
# iteration 700 / 1000: loss 2.145262
# iteration 800 / 1000: loss 2.177011
# iteration 900 / 1000: loss 2.178770
# iteration 0 / 1000: loss 2.302684
# iteration 100 / 1000: loss 2.304285
# iteration 200 / 1000: loss 2.276258
# iteration 300 / 1000: loss 2.240702
# iteration 400 / 1000: loss 2.225984
# iteration 500 / 1000: loss 2.241269
# iteration 600 / 1000: loss 2.240963
# iteration 700 / 1000: loss 2.147939
# iteration 800 / 1000: loss 2.179602
# iteration 900 / 1000: loss 2.180208
# iteration 0 / 1000: loss 2.302684
# iteration 100 / 1000: loss 2.304236
# iteration 200 / 1000: loss 2.281427
# iteration 300 / 1000: loss 2.243486
# iteration 400 / 1000: loss 2.232461
# iteration 500 / 1000: loss 2.243231
# iteration 600 / 1000: loss 2.242213
# iteration 700 / 1000: loss 2.150461
# iteration 800 / 1000: loss 2.182307
# iteration 900 / 1000: loss 2.183184
# iteration 0 / 1000: loss 2.302684
# iteration 100 / 1000: loss 2.304181
# iteration 200 / 1000: loss 2.288349
# iteration 300 / 1000: loss 2.246779
# iteration 400 / 1000: loss 2.237205
# iteration 500 / 1000: loss 2.246335
# iteration 600 / 1000: loss 2.245405
# iteration 700 / 1000: loss 2.158572
# iteration 800 / 1000: loss 2.187196
# iteration 900 / 1000: loss 2.185320
# 0.4153999984264374
# Saved in ./nn_best_model.pt

# %%
# Check the validation-set accuracy of your best model
y_val_preds = best_net.predict(data_dict['X_val'])
val_acc = 100 * (y_val_preds == data_dict['y_val']).double().mean().item()
print('Best val-set accuracy: %.2f%%' % val_acc)
# Out:
# Best val-set accuracy: 41.54%

# %%
from eecs598.a2_helpers import show_net_weights
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# ### Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set. To get full credit for the assignment, you should achieve over 50% classification accuracy on the test set.
#
# (Our best model gets 56.03% test-set accuracy -- did you beat us?)

# %%
y_test_preds = best_net.predict(data_dict['X_test'])
test_acc = 100 * (y_test_preds == data_dict['y_test']).double().mean().item()
print('Test accuracy: %.2f%%' % test_acc)
# Out:
# Test accuracy: 41.73%
